# %% [markdown]
# # Please select a partner on your own and sign up [here](https://docs.google.com/spreadsheets/d/1XGmHu51l7mYXGrEIbxZ5kZeyxGoqVwEcBKnQQVf3A00/edit?usp=sharing)
#
# ***

# %% [markdown]
# ### Your name:
#
# ### Your partner's name:
#
# #### Each individual student will be required to report individual logs for each assignment, describing:
#
# * time spent driving, observing, and working alone.
#
# Your answer:
#
# * confidence in solution.
#
# Your answer:
#
# * satisfaction with the experience.
#
# Your answer:
#
# #### Any comments or suggestions for this lab?
#
# Your answer:

# %%
# Load packages
import pandas as pd
import numpy as np
import math

# %%
df = pd.DataFrame({"Refund" : ["Yes","No","No","Yes","No","No","Yes","No","No","No"],
                   "MartialStatus" : ["Single","Married","Single","Married","Divorced","Married","Divorced","Single","Married","Single"],
                   "Income" : [125,100,70,120,95,60,220,85,75,90],
                   "Cheat" : ["No","No","No","No","Yes","No","No","Yes","No","Yes"]})
df = df[["Refund","MartialStatus","Income","Cheat"]]

df
# Out:
#   Refund MartialStatus  Income Cheat
# 0    Yes        Single     125    No
# 1     No       Married     100    No
# 2     No        Single      70    No
# 3    Yes       Married     120    No
# 4     No      Divorced      95   Yes
# 5     No       Married      60    No
# 6    Yes      Divorced     220    No
# 7     No        Single      85   Yes
# 8     No       Married      75    No
# 9     No        Single      90   Yes

# %% [markdown]
# # Question: Use Gini index to choose a best feature and a best splitting point as the root of the decision tree. You do not need to build the whole tree!!
#
# # You only need to consider binary split.
#
# ### For "Refund" feature, two children are Yes and No.
# ### For "MartialStatus" feature, two children could be Married and Not Married, Divorced and Not Divorced, or Single and Not Single.
# ### For "Income" feature, please refer the picture in slide 40 to choose one splitting point. For example, two children are "> 80" and "< 80" if the splitting point is 80.

# %%
data = df.iloc[:,:-1].as_matrix()  # First three columns
target = df.iloc[:,-1].as_matrix() # Last column

# step 1: How to calculate Gini index for one node? 
def gini_node(node):
    # This node could be either a parent or a child.
    # node: a list of classes of all instances at current node. For example, node = [yes, yes, no, no, yes]
    if len(node)==0:
        return 0
    gini = 1
    # Your code goes here:

    
    return gini



# step 2: How to combine Gini indexes of two children?
def gini_children(leftchild, rightchild):
    # Your code goes here:
    
    
    
    return 



# step 3: How to calculate value of Gain?
def gain(parent, leftchild, rightchild):
    # Your code goes here:
    
    
    return 



# step 4: What is the value of gain if choosing "Refund"?
# Slice out left child and right child. Then call gain(parent, leftchild, rightchild)

refund = data[:,0]
# Your code goes here:





# step 5: What is the value of gain if choosing "MartialStatus"? Which splitting method is the best one?
# There 3 different split methods if choosing "MartialStatus".
# For each split method, slice out left child and right child and then call gain(parent, leftchild, rightchild)

martial= data[:,1]
# Your code goes here:





# step 6: What is the value of gain if choosing "Income"? Which splitting point is the best one?
# There 11 different split methods if choosing "Income".
# For each split method, slice out left child and right child and then call gain(parent, leftchild, rightchild)

income = np.array(data[:,2],dtype=float)
# Your code goes here:





# step 7: Choose a best feature and splitting method.
# Your code goes here:
